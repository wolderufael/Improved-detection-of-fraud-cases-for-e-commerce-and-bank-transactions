# %% [markdown]
# # Prediction using ML models

# %% [markdown]
# ### Adding project path to system path

# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Import modules

# %%
from script.modelling import Modelling
modelling=Modelling()

# %% [markdown]
# ### Load the preprocessed fraud data

# %%
fraud_data=pd.read_csv("Data/preprocessed_data.csv")

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test=modelling.split_data(fraud_data)

# %% [markdown]
# ## Train using LogesticRegression model

# %%
modelling.train_with_ml_model(X_train, X_test, y_train, y_test,"LogisticRegression")
# Out:
# Accuracy: 0.9039335122857732
# 2024/10/22 15:38:39 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 46b72b0172344d188ae256f18a5594d7

# %% [markdown]
# ## Train using RandomForrestClassifier model

# %%
modelling.train_with_ml_model(X_train, X_test, y_train, y_test,"RandomForrestClassifier")
