# %% [markdown]
# # Prediction using ML models for  fraud-data

# %% [markdown]
# ### Adding project path to system path

# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Import modules

# %%
from script.modelling import Modelling
modelling=Modelling()

# %% [markdown]
# ### Load the preprocessed fraud data

# %%
credit_card_data=pd.read_csv("Data/credit_card_preprocessed_data.csv")

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test=modelling.split_creditcard_data(credit_card_data)

# %% [markdown]
# ## Train using LogesticRegression model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"LogisticRegression")
# Out:
# Accuracy: 0.9992743700478681
# 2024/10/28 14:58:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 479477c4f1b643fd9fe9c9d3f2328eb6
# Model saved as models/creditcard/LogisticRegression-28-10-2024-14-58-46-00.pkl

# %% [markdown]
# ## Train using DecisionTreeClassifier model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"DecisionTreeClassifier")
# Out:
# Accuracy: 0.9993797034280163
# 2024/10/28 14:59:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 67487a41d75b4bfa9ccd4f7cb70165e6
# Model saved as models/creditcard/DecisionTreeClassifier-28-10-2024-14-59-48-00.pkl

# %% [markdown]
# ## Train using RandomForrestClassifier model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"RandomForestClassifier")
# Out:
# Accuracy: 0.9996137776061234
# 2024/10/28 15:08:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 2033a8058b4f41b283013a947e3838d0
# Model saved as models/creditcard/RandomForestClassifier-28-10-2024-15-08-21-00.pkl

# %% [markdown]
# ## Training using GradientBoostingClassifier model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"GradientBoostingClassifier")
# Out:
# Accuracy: 0.9985838512224524
# 2024/10/28 15:20:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 0b02d794dac641d6ad94bbe6d250ec22
# Model saved as models/creditcard/GradientBoostingClassifier-28-10-2024-15-20-04-00.pkl

# %% [markdown]
# ## Training using MLPClassifier model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"MLPClassifier")
# Out:
# Accuracy: 0.9995201479348805
# 2024/10/28 15:21:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 36478b1a27404d4b8ce1f8d5409e598a
# Model saved as models/creditcard/MLPClassifier-28-10-2024-15-21-31-00.pkl

# %% [markdown]
# ## Training using CNN model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"CNN")
# Out:
# Epoch 1/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.9990 - loss: 0.0133 - val_accuracy: 0.9984 - val_loss: 0.0039
# Epoch 2/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9992 - loss: 0.0043 - val_accuracy: 0.9994 - val_loss: 0.0032
# Epoch 3/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 22s 4ms/step - accuracy: 0.9992 - loss: 0.0040 - val_accuracy: 0.9994 - val_loss: 0.0037
# Epoch 4/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 23s 5ms/step - accuracy: 0.9992 - loss: 0.0042 - val_accuracy: 0.9994 - val_loss: 0.0033
# Epoch 5/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 24s 5ms/step - accuracy: 0.9993 - loss: 0.0040 - val_accuracy: 0.9994 - val_loss: 0.0033
# Epoch 6/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 39s 4ms/step - accuracy: 0.9992 - loss: 0.0040 - val_accuracy: 0.9993 - val_loss: 0.0029
# Epoch 7/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9993 - loss: 0.0036 - val_accuracy: 0.9993 - val_loss: 0.0040
# Epoch 8/10
# ...

# %% [markdown]
# ## Training using RNN model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"RNN")
# Out:
# Epoch 1/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 43s 8ms/step - accuracy: 0.9911 - loss: 0.6931 - val_accuracy: 0.9981 - val_loss: 0.0054
# Epoch 2/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 44s 9ms/step - accuracy: 0.9985 - loss: 0.0056 - val_accuracy: 0.9992 - val_loss: 0.0039
# Epoch 3/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 67s 6ms/step - accuracy: 0.9991 - loss: 0.0066 - val_accuracy: 0.9992 - val_loss: 0.0045
# Epoch 4/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 33s 7ms/step - accuracy: 0.9991 - loss: 0.0050 - val_accuracy: 0.9993 - val_loss: 0.0046
# Epoch 5/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - accuracy: 0.9992 - loss: 0.0052 - val_accuracy: 0.9993 - val_loss: 0.0045
# Epoch 6/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 26s 5ms/step - accuracy: 0.9993 - loss: 0.0047 - val_accuracy: 0.9993 - val_loss: 0.0040
# Epoch 7/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 25s 5ms/step - accuracy: 0.9992 - loss: 0.0045 - val_accuracy: 0.9993 - val_loss: 0.0039
# Epoch 8/10
# ...

# %% [markdown]
# ## Training using LSTM model

# %%
modelling.predict_fraud_for_creditcard(X_train, X_test, y_train, y_test,"LSTM")
# Out:
# Epoch 1/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 67s 13ms/step - accuracy: 0.9965 - loss: 174664.4688 - val_accuracy: 0.9982 - val_loss: 0.2054
# Epoch 2/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 61s 12ms/step - accuracy: 0.9982 - loss: 0.0858 - val_accuracy: 0.9982 - val_loss: 0.0150
# Epoch 3/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 61s 12ms/step - accuracy: 0.9981 - loss: 0.0139 - val_accuracy: 0.9980 - val_loss: 0.0125
# Epoch 4/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 60s 12ms/step - accuracy: 0.9983 - loss: 0.0117 - val_accuracy: 0.9981 - val_loss: 0.0095
# Epoch 5/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 53s 11ms/step - accuracy: 0.9983 - loss: 0.0095 - val_accuracy: 0.9990 - val_loss: 0.0046
# Epoch 6/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 59s 12ms/step - accuracy: 0.9986 - loss: 0.0059 - val_accuracy: 0.9982 - val_loss: 0.0230
# Epoch 7/10
# 4985/4985 ━━━━━━━━━━━━━━━━━━━━ 58s 12ms/step - accuracy: 0.9986 - loss: 0.0071 - val_accuracy: 0.9992 - val_loss: 0.0040
# Epoch 8/10
# ...
