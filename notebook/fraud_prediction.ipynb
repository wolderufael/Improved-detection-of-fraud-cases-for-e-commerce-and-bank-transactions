# %% [markdown]
# # Prediction using ML models for  fraud-data

# %% [markdown]
# ### Adding project path to system path

# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
notebook_dir = os.getcwd()
parent_path=os.path.dirname(notebook_dir)

os.chdir(parent_path)

# %% [markdown]
# ### Import modules

# %%
from script.modelling import Modelling
modelling=Modelling()

# %% [markdown]
# ### Load the preprocessed fraud data

# %%
fraud_data=pd.read_csv("Data/preprocessed_data.csv")

# %% [markdown]
# ## Train-Test Split

# %%
X_train, X_test, y_train, y_test=modelling.split_data(fraud_data)

# %% [markdown]
# ## Train using LogesticRegression model

# %%
modelling.train_with_ml_model(X_train, X_test, y_train, y_test,"LogisticRegression")
# Out:
# Accuracy: 0.9039335122857732
# 2024/10/22 22:27:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 8a94a2a625f84278844a1882a943520a
# Model saved as models/fraud_data/LogisticRegression-22-10-2024-22-27-18-00.pkl

# %% [markdown]
# ## Train using DecisionTreeClassifier model

# %%
modelling.train_with_ml_model(X_train, X_test, y_train, y_test,"DecisionTreeClassifier")
# Out:
# Accuracy: 0.9039335122857732
# 2024/10/22 22:27:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 715314fc2c654fdca5a58f1ca17e82de
# Model saved as models/fraud_data/DecisionTreeClassifier-22-10-2024-22-27-33-00.pkl

# %% [markdown]
# ## Train using RandomForrestClassifier model

# %%
modelling.train_with_ml_model(X_train, X_test, y_train, y_test,"RandomForestClassifier")
# Out:
# Accuracy: 0.9543929382614083
# 2024/10/22 22:28:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: 2ee87dc25d334c2c9ff5d679f2520e0f
# Model saved as models/fraud_data/RandomForestClassifier-22-10-2024-22-28-18-00.pkl

# %% [markdown]
# ## Training using GradientBoostingClassifier model

# %%
modelling.train_with_ml_model(X_train, X_test, y_train, y_test,"GradientBoostingClassifier")
# Out:
# Accuracy: 0.9039335122857732
# 2024/10/22 22:28:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Run ID: d351cc19c1884a4fb5ba5992d9d49af3
# Model saved as models/fraud_data/GradientBoostingClassifier-22-10-2024-22-28-46-00.pkl
